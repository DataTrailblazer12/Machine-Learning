# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn import linear_model

# %%
df=pd.read_csv('C:/Users/yoges/OneDrive/Desktop/data.csv')
df
# Out:
#    sqft   price
# 0  1200  240000
# 1  1500  300000
# 2  1700  340000
# 3  2000  400000
# 4  2300  460000
# 5  2500  500000
# 6  2700  540000
# 7  3000  600000
# 8  3200  640000
# 9  3500  700000

# %%
df.describe()
# Out:
#               sqft          price
# count    10.000000      10.000000
# mean   2360.000000  472000.000000
# std     760.409247  152081.849308
# min    1200.000000  240000.000000
# 25%    1775.000000  355000.000000
# 50%    2400.000000  480000.000000
# 75%    2925.000000  585000.000000
# max    3500.000000  700000.000000

# %%
df.isna()
# Out:
#     sqft  price
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False
# 5  False  False
# 6  False  False
# 7  False  False
# 8  False  False
# 9  False  False

# %%
df.columns
# Out:
# Index(['sqft', 'price'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sqft    10 non-null     int64
#  1   price   10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes

# %%
df.head()
# Out:
#    sqft   price
# 0  1200  240000
# 1  1500  300000
# 2  1700  340000
# 3  2000  400000
# 4  2300  460000

# %%
df.head(3)
# Out:
#    sqft   price
# 0  1200  240000
# 1  1500  300000
# 2  1700  340000

# %%
df.tail()
# Out:
#    sqft   price
# 5  2500  500000
# 6  2700  540000
# 7  3000  600000
# 8  3200  640000
# 9  3500  700000

# %%
df.tail(2)
# Out:
#    sqft   price
# 8  3200  640000
# 9  3500  700000

# %%
df.dropna()
# Out:
#    sqft   price
# 0  1200  240000
# 1  1500  300000
# 2  1700  340000
# 3  2000  400000
# 4  2300  460000
# 5  2500  500000
# 6  2700  540000
# 7  3000  600000
# 8  3200  640000
# 9  3500  700000

# %%
df.notna()
# Out:
#    sqft  price
# 0  True   True
# 1  True   True
# 2  True   True
# 3  True   True
# 4  True   True
# 5  True   True
# 6  True   True
# 7  True   True
# 8  True   True
# 9  True   True

# %%
df.drop_duplicates()
# Out:
#    sqft   price
# 0  1200  240000
# 1  1500  300000
# 2  1700  340000
# 3  2000  400000
# 4  2300  460000
# 5  2500  500000
# 6  2700  540000
# 7  3000  600000
# 8  3200  640000
# 9  3500  700000

# %%
plt.xlabel('sqft')
plt.ylabel('price')
plt.plot(df.sqft,df.price,color='purple',marker='o')

# %%
plt.scatter(df.sqft,df.price,color='purple')

# %%
a=df[['sqft']]
b=df['price']

# %%
yogi= LinearRegression()
yogi.fit(a,b)
# Out:
# LinearRegression()

# %%
yogi.coef_
# Out:
# array([200.])

# %%
yogi.intercept_
# Out:
# -1.1641532182693481e-10

# %%
yogi.score(a,b)
# Out:
# 1.0

# %%
x=np.array([[4000]])
pr_value=yogi.predict(x)
print(pr_value)
# Out:
# [800000.]
# C:\Users\yoges\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
yogi2=linear_model.LinearRegression()
yogi2.fit(df[['sqft']],df.price)
# Out:
# LinearRegression()

# %%
yogi2.intercept_
# Out:
# -1.1641532182693481e-10

# %%
yogi2.coef_
# Out:
# array([200.])

# %%
yogi2.predict([[5000]])
# Out:
# C:\Users\yoges\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1000000.])

# %%
for i in range(1000,10000,1000):
    print(yogi2.predict([[i]]))
# Out:
# [200000.]
# [400000.]
# [600000.]
# [800000.]
# [1000000.]
# [1200000.]
# [1400000.]
# [1600000.]
# [1800000.]
# C:\Users\yoges\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\yoges\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\yoges\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\yoges\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
